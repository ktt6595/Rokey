# %% [markdown]
# 문항 1. 동영상 파일 열기 검증 cv2.VideoCapture 클래스를 사용하여 동영상 파일을 열었을 때, 파일 경로가 잘못되었거나 코덱 문제로 열리지 않는 경우가 있습니다. 이때 객체가 정상적으로 초기화되었는지(파일이 잘 열렸는지) 확인하기 위해 사용하는 메서드(함수)의 이름을 적으세요.

# %% [markdown]
# 답변 작성란: isOpened
#
# 메서드 이름: ㄱㄹ

# %% [markdown]
# 문항 2. 키 입력 대기 함수 동영상을 재생할 때 프레임 사이의 간격을 조절하거나 사용자 입력을 받기 위해 cv2.waitKey(delay) 함수를 사용합니다. 이때 인자 delay에 들어가는 **값의 의미(단위)** 는 무엇이며, 만약 0을 넣으면 어떻게 동작하는지 설명하세요.

# %% [markdown]
# 답변 작성란:
#
# delay 값의 단위: 밀리 초(ms)
#
# 0을 입력했을 때의 동작: 키 입력이 있을 때까지 무한히 대기

# %% [markdown]
# 문항 3. 동영상 객체 생성 및 예외 처리 bird.mp4 파일을 읽어오는 VideoCapture 객체 cap을 생성하고, 파일이 정상적으로 열리지 않았을 경우 에러 메시지를 출력하고 종료하는 코드를 작성하세요.

# %%
import cv2

video_path = 'bird.mp4'

# TODO: VideoCapture 객체 생성
cap = cv2.VideoCapture(video_path)# (코드를 입력하세요)

# TODO: 파일이 열렸는지 확인 (열리지 않았으면 에러 출력)
if not cap.isOpened():# (코드를 입력하세요) :
    print("ERR : 파일을 열 수 없습니다.")
    exit()
# Out:
# ERR : 파일을 열 수 없습니다.

# %% [markdown]
# 문항 4. 동영상 속성 정보 확인 위에서 생성한 cap 객체를 이용하여 동영상의 초당 프레임 수(FPS), 가로 폭(Width), 세로 높이(Height) 정보를 가져와 출력하는 코드를 작성하세요. (힌트: cap.get() 메서드와 cv2.CAP_PROP_ 상수를 사용하세요.)

# %%
# TODO: FPS, Width, Height 속성 가져오기
fps = cap.get(cv2.CAP_PROP_FPS)# 코드를 입력하세요 )
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))# 코드를 입력하세요 ))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))# 코드를 입력하세요 ))
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f'fps: {fps}, width: {width}, height: {height}, count: {frame_count}')
# Out:
# fps: 0.0, width: 0, height: 0, count: 0

# %% [markdown]
# 문항 5. 프레임 읽기 및 그레이스케일 변환 while 반복문을 사용하여 동영상의 프레임을 한 장씩 읽어오고(read), 읽어온 프레임이 있다면 이를 **그레이스케일(Grayscale)** 로 변환하여 cv2.imshow로 출력하는 코드를 작성하세요. (종료 조건은 다음 문제에서 작성합니다.)

# %%
from google.colab.patches import cv2_imshow # Colab에서 이미지 표시를 위해 필요합니다.

while True:
    # TODO: 프레임 읽기 (ret: 성공여부, frame: 이미지데이터)
    result, frame = cap.read()

    # 프레임을 더 이상 읽을 수 없으면(동영상 끝) 반복 종료
    if not result:
        break

    # TODO: 읽은 프레임을 흑백(Grayscale)으로 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 화면 출력
    cv2_imshow(gray)  # 콜랩에서 이미지 출력 (cv2.imshow 대신 사용)

    # 콜랩 환경에서는 cv2.waitKey를 통한 키 입력 대기가 제대로 동작하지 않으므로 제거합니다.
    # 동영상 종료 조건은 'if not result:'로 충분합니다.

# %% [markdown]
# 문항 6. 자원 해제 동영상 재생이 끝나거나 사용자가 종료했을 때, 열려 있는 비디오 캡처 객체를 해제하고 생성된 모든 윈도우 창을 닫는 코드를 작성하세요.

# %%
# TODO: 캡처 객체 자원 해제
cap.release()
# (코드를 입력하세요)

# TODO: 모든 OpenCV 윈도우 닫기
# 콜랩 환경에서는 GUI 윈도우 개념이 없으므로 cv2.destroyAllWindows()는 필요하지 않으며, 오류를 발생시킬 수 있습니다.
# cv2.destroyAllWindows() # 해당 함수는 Colab에서 지원되지 않아 주석 처리합니다.
# (코드를 입력하세요)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-3940574890.py in <cell line: 0>()
#       4
#       5 # TODO: 모든 OpenCV 윈도우 닫기
# ----> 6 cv2.destroyAllWindows()
#       7 # (코드를 입력하세요)
#
# error: OpenCV(4.12.0) /io/opencv/modules/highgui/src/window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
